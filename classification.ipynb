# %% [markdown]
# Multicalss Classification problem.
# Given four input features and then classify the iris dataset flowers into 3 classes

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import numpy as np

# iris is already defined in the notebook
df = pd.DataFrame(iris.data, columns=iris.feature_names)  # use 'columns'
df['Species'] = iris.target
print(df.head())
print("Shape: ", df.shape)
df.info()           # don't wrap in print()
print(df.describe())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# Shape:  (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# ...

# %%
print(df.isnull().sum()) #use this to detect if there is missing value
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['sepal width (cm)'])
plt.show()

sns.boxplot(x=df['petal width (cm)'])
plt.show()

sns.boxplot(x=df['sepal length (cm)'])
plt.show()

sns.boxplot(x=df['petal length (cm)'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['sepal width (cm)'])
plt.show()

sns.boxplot(x=df['petal width (cm)'])
plt.show()

sns.boxplot(x=df['sepal length (cm)'])
plt.show()

sns.boxplot(x=df['petal length (cm)'])
plt.show()

# %%
sns.countplot(x='Species', data=df)
plt.show()

# %%
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='Species', data=df)
plt.show()

# %%
#correlation matrix
corr=df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#correlation matrix
corr=df.drop('sepal width (cm)', axis=1).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
