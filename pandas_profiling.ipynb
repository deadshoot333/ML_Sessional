# %% [markdown]
# Pandas profiling is used to visualize the dataset with all sort of graphs

# %%
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.datasets import load_wine
import seaborn as sns
import matplotlib.pyplot as plt
 
iris=load_wine()
df = pd.DataFrame(iris.data, columns=iris.feature_names)  # use 'columns'
df['alcohol'] = iris.target
print(df.head())

profile = ProfileReport(df,title="Pandas Profiling Report")
profile.to_file("report.html")
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0        0        1.71  2.43               15.6      127.0           2.80
# 1        0        1.78  2.14               11.2      100.0           2.65
# 2        0        2.36  2.67               18.6      101.0           2.80
# 3        0        1.95  2.50               16.8      113.0           3.85
# 4        0        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0
# 100%|██████████| 13/13 [00:00<?, ?it/s]18 [00:00<00:00, 36.52it/s, Describe variable: proline]
# Summarize dataset: 100%|██████████| 166/166 [00:26<00:00,  6.29it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:07<00:00,  7.03s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.39it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 40.63it/s]
